# %% [markdown]
# # Topic 4: Variables & Data Types - Exercises
#
# ## Instructions
# Complete each exercise by writing code in the cells provided.
#
# **Remember:**
# - Variables are containers for storing data
# - Four main types: int, float, str, bool
# - Use descriptive variable names
# - Check types with `type()`
#
# ---

# %% [markdown]
# ## Exercise 1: Creating Variables
#
# Create four variables:
# 1. `my_name` - your name (string)
# 2. `my_age` - your age (integer)
# 3. `my_height` - your height in feet (float)
# 4. `is_student` - whether you're a student (boolean)
#
# Print all four variables.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 2: Checking Data Types
#
# Create the following variables and print their types:
# - `score = 100`
# - `price = 29.99`
# - `product = "Laptop"`
# - `available = True`

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 3: String vs Number
#
# Create two variables:
# - `number1 = 42` (integer)
# - `number2 = "42"` (string)
#
# Print both variables and their types. What's the difference?

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 4: Updating Variables
#
# 1. Create a variable `counter = 0`
# 2. Print it
# 3. Update it to 5
# 4. Print it again
# 5. Update it to 10
# 6. Print it one more time

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 5: String Concatenation
#
# Create three variables:
# - `first_name` with your first name
# - `last_name` with your last name
# - `full_name` that combines them with a space in between
#
# Print the full name.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 6: String Repetition
#
# Create a variable `symbol = "*"` and print it 20 times in a row using string repetition.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 7: String Length
#
# Create a variable with your favorite quote or sentence, then print:
# 1. The quote
# 2. Its length (number of characters)

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 8: Multiple Assignment
#
# Use multiple assignment to create three variables in one line:
# - `city` = "Dallas"
# - `state` = "Texas"
# - `zip_code` = 75201
#
# Print all three.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 9: Personal Profile
#
# Create variables for a personal profile:
# - Name (string)
# - Age (integer)
# - GPA (float)
# - Is enrolled (boolean)
#
# Print them in a nicely formatted way.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 10: Product Catalog
#
# Create variables for a product in an online store:
# - Product name
# - Price
# - Quantity in stock
# - Is on sale (boolean)
#
# Print a formatted product description.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Challenge Exercise 1: Variable Swap
#
# Create two variables:
# - `a = 10`
# - `b = 20`
#
# Print their values, then swap them (so a becomes 20 and b becomes 10), then print again.
#
# Hint: You might need a temporary third variable!

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Challenge Exercise 2: Restaurant Bill
#
# Create variables for a restaurant bill:
# - Restaurant name
# - Number of people
# - Total bill amount
# - Tax rate (as a decimal, e.g., 0.08 for 8%)
#
# Print a formatted receipt showing all information.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Challenge Exercise 3: About Me Page
#
# Create an "About Me" display using at least 6 different variables of different types.
# Include:
# - Personal information (name, age, etc.)
# - Interests or hobbies
# - Goals or facts about yourself
#
# Format it nicely with headers and spacing!

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Bonus Challenge: Type Exploration
#
# Create variables with different values and explore what types they become:
# 1. What type is `x = 5`?
# 2. What type is `y = 5.0`?
# 3. What type is `z = "5"`?
# 4. What happens when you print `x + y`?
# 5. Can you add `x + z`? Try it (you might get an error - that's okay!)

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Reflection
#
# Excellent work! You've practiced:
# - Creating variables of different types
# - Checking data types
# - Updating variables
# - String operations (concatenation, repetition, length)
# - Multiple assignment
# - Building formatted outputs
#
# **Next:** Check the solutions, then move on to Basic Operators!
