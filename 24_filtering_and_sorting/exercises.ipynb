# %% [markdown]
# # Topic 24 Exercises: Filtering and Sorting

# %% [markdown]
# ## Exercise 1Filter DataFrame to show only rows where Age > 30.

# %%
import pandas as pd# Your code here

# %% [markdown]
# ## Exercise 2Sort DataFrame by a specific column.

# %%
# Your code here
