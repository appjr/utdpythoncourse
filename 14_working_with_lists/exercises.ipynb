# %% [markdown]
# # Topic 14: List Slicing - Exercises
#
# Practice indexing and slicing.
#
# ---

# %% [markdown]
# ## Exercise 1: Access Items
# Given `numbers = [10, 20, 30, 40, 50]`, print first, last, and middle items.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 2: Slicing
# Get first 3 items, last 3 items, and every 2nd item from a list.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 3: Reverse List
# Reverse a list using slicing.

# %%
# Write your code here

# %% [markdown]
# ## Challenge: List Statistics
# Calculate and print: length, sum, average, max, min of a number list.

# %%
# Write your code here
