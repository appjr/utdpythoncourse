# %% [markdown]
# # Topic 3: Hello World - Exercises
#
# ## Instructions
# Complete each exercise in the code cells provided. Run your code to test it.
#
# **Tips:**
# - Read each question carefully
# - Test your code after writing it
# - If you get an error, read the message and try to fix it
# - Don't be afraid to experiment!
#
# ---

# %% [markdown]
# ## Exercise 1: Basic Print Statements
#
# Write a program that prints "Hello, Python!" to the screen.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 2: Multiple Print Statements
#
# Write a program that prints three lines:
# 1. Your name
# 2. Your favorite hobby
# 3. Why you're learning Python

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 3: Using Comments
#
# Write a program that:
# 1. Has a comment explaining what the program does
# 2. Prints "Learning Python is fun!"
# 3. Has a comment after the print statement

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 4: Printing Numbers
#
# Write a program that prints:
# 1. Your age (as a number, not in quotes)
# 2. Your birth year
# 3. Your favorite number

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 5: Mixing Text and Numbers
#
# Write a program that prints: "I am [age] years old" where [age] is your age.
#
# Hint: Use commas to separate text and numbers in the print statement.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 6: Using Escape Characters
#
# Write a program that prints the following on separate lines using the `\n` escape character:
# ```
# Line 1
# Line 2
# Line 3
# ```
#
# Do this using only ONE print statement.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 7: Tab Formatting
#
# Create a simple menu using tabs (`\t`) for spacing:
# ```
# MENU
# Pizza    $12.99
# Burger   $8.99
# Salad    $6.99
# ```

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 8: Custom Separator
#
# Print the following words with a hyphen (-) between them: Python, Java, JavaScript
#
# Expected output: `Python-Java-JavaScript`
#
# Hint: Use the `sep` parameter.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 9: Creating a Box
#
# Create a box pattern using asterisks:
# ```
# **********
# *        *
# *        *
# **********
# ```

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 10: Personal Information Card
#
# Create a formatted personal information card that displays:
# - A header with your name
# - Your email
# - Your phone number
# - Your city
#
# Make it look professional using formatting techniques you've learned (tabs, blank lines, separators, etc.).
#
# Example output:
# ```
# ========================
#     CONTACT INFO
# ========================
# Name:    John Doe
# Email:   john@email.com
# Phone:   555-1234
# City:    Dallas
# ========================
# ```

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Challenge Exercise 1: ASCII Art
#
# Create a simple ASCII art design of your choice. Here are some ideas:
# - A smiley face
# - A house
# - A tree
# - Your initials
#
# Be creative!

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Challenge Exercise 2: Multi-line Quote
#
# Print your favorite quote or saying. Format it nicely with:
# - The quote text
# - The author's name
# - Proper spacing and formatting
#
# Example:
# ```
# "The only way to do great work is to love what you do."
#                                         - Steve Jobs
# ```

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Challenge Exercise 3: Story Printer
#
# Write a program that prints a very short story (3-5 sentences). Use:
# - Multiple print statements
# - Comments to organize your code
# - Blank lines between paragraphs
# - Good formatting
#
# Make it creative and fun!

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Bonus Challenge: Calculator Display
#
# Create a simple calculator display that shows:
# ```
# +-------------------+
# |                   |
# |        12 + 8     |
# |        = 20       |
# |                   |
# +-------------------+
# ```
#
# Hint: Use escape characters and careful spacing.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Reflection
#
# Great job completing these exercises!
#
# **What you've practiced:**
# - Using the print() function
# - Writing comments
# - Working with strings and numbers
# - Using escape characters
# - Formatting output
# - Creating visual displays
#
# **Next:** Check the solutions notebook to compare your answers, then move on to the next lesson on Variables & Data Types!
