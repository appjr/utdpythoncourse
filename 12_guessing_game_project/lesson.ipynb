# %% [markdown]
# # Topic 12: Project - Simple Guessing Game
#
# ## Learning Objectives
# - Combine all concepts learned so far
# - Build a complete interactive program
# - Use loops, conditionals, and user input
# - Practice problem-solving
#
# ---

# %% [markdown]
# ## Project Overview
#
# Build a number guessing game where:
# 1. Computer picks a random number (1-100)
# 2. Player guesses the number
# 3. Program gives hints (too high/too low)
# 4. Tracks number of attempts
# 5. Congratulates player when correct
#
# ---

# %% [markdown]
# ## Complete Game Code

# %%
import random

# Game setup
print("=== Number Guessing Game ===")
print("I'm thinking of a number between 1 and 100")

secret_number = random.randint(1, 100)
attempts = 0
max_attempts = 10

# Game loop
while attempts < max_attempts:
    try:
        guess = int(input(f"\nAttempt {attempts + 1}/{max_attempts} - Enter your guess: "))
        attempts += 1
        
        if guess < 1 or guess > 100:
            print("Please guess between 1 and 100!")
            continue
        
        if guess < secret_number:
            print("📈 Too low! Try higher.")
        elif guess > secret_number:
            print("📉 Too high! Try lower.")
        else:
            print(f"\n🎉 Correct! You guessed it in {attempts} attempts!")
            break
    
    except ValueError:
        print("Invalid input! Please enter a number.")
        continue

if attempts == max_attempts and guess != secret_number:
    print(f"\n😞 Game Over! The number was {secret_number}")

print("Thanks for playing!")

# %% [markdown]
# ## Concepts Used
#
# This project demonstrates:
# - ✅ Variables and data types
# - ✅ User input and type casting
# - ✅ Conditional statements (if/elif/else)
# - ✅ while loops
# - ✅ Loop control (break, continue)
# - ✅ Comparison operators
# - ✅ Random module
# - ✅ Error handling (try/except)
#
# ---

# %% [markdown]
# ## Enhancements to Try
#
# 1. Add difficulty levels (easy/medium/hard)
# 2. Track high scores
# 3. Add a play again option
# 4. Show remaining attempts
# 5. Give better hints (warmer/colder)
#
# ---
#
# ## Congratulations! 🎉
#
# You've completed Section 2: Control Flow!
#
# **Next Section**: Data Structures (Lists & Dictionaries)
