# %% [markdown]
# # Topic 12: Guessing Game Project - Exercises
#
# Build your own variations of the guessing game!
#
# ---

# %% [markdown]
# ## Exercise 1: Basic Guessing Game
# Create a guessing game where computer picks 1-50, user has 7 attempts.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 2: Add Play Again
# Add option to play multiple rounds.

# %%
# Write your code here

# %% [markdown]
# ## Challenge: Reverse Guessing Game
# User thinks of number, computer guesses! User says "higher" or "lower".

# %%
# Write your code here
