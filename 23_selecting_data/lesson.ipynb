# %% [markdown]
# # Topic 23: Selecting Data## Learning Objectives- Select columns from DataFrame- Select rows using loc and iloc---

# %% [markdown]
# ## 23.1 Selecting Columns

# %%
import pandas as pddf = pd.read_csv('data.csv')print(df['Name'])

# %% [markdown]
# ## 23.2 Selecting Rows with loc

# %%
# Select by labelprint(df.loc[0])

# %% [markdown]
# ## 23.3 Selecting with iloc

# %%
# Select by positionprint(df.iloc[0])

# %% [markdown]
# ---## Key Takeaways✅ Use `df['column']` to select columns✅ Use `.loc[]` for label-based selection✅ Use `.iloc[]` for position-based selection---
