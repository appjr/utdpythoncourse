# %% [markdown]
# # Topic 19 Exercises: Reading & Writing Text Files
#
# Complete the following exercises to practice file operations.

# %% [markdown]
# ## Exercise 1: Create and Write
#
# Create a file called `my_file.txt` and write 3 lines to it.

# %%
# Your code here
with open('my_file.txt', 'w') as file:
    # Write your lines here
    pass

print("File created!")

# %% [markdown]
# ## Exercise 2: Read and Display
#
# Read the contents of `my_file.txt` and print each line.

# %%
# Your code here
with open('my_file.txt', 'r') as file:
    # Read and print lines
    pass

# %% [markdown]
# ## Exercise 3: Append to File
#
# Append 2 more lines to `my_file.txt`.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4: Count Lines
#
# Write a function that counts the number of lines in a file.

# %%
def count_lines(filename):
    # Your code here
    pass

# Test it
print("Number of lines:", count_lines('my_file.txt'))
