# %% [markdown]
# # Topic 9: while Loops - Exercises
#
# ## Instructions
# Practice using while loops.
#
# **Remember:** Always update the loop variable!
#
# ---

# %% [markdown]
# ## Exercise 1: Count to 10
# Use a while loop to print numbers 1 to 10.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 2: Countdown
# Count down from 10 to 1, then print "Blast off!"

# %%
# Write your code here

# %% [markdown]
# ## Exercise 3: Sum Numbers
# Calculate sum of numbers 1 to 100 using a while loop.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 4: Password Retry
# Ask for password. Give 3 attempts. If correct, print "Access granted", else "Locked out".

# %%
# Write your code here

# %% [markdown]
# ## Challenge: Guess the Number
# Set secret_number = 7. Let user guess until correct. Count attempts.

# %%
# Write your code here
