# %% [markdown]
# # Topic 10: for Loops & range() - Exercises
#
# Practice using for loops and range().
#
# ---

# %% [markdown]
# ## Exercise 1: Print 1 to 10
# Use for loop and range() to print numbers 1 to 10.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 2: Even Numbers
# Print all even numbers from 0 to 20.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 3: Multiplication Table
# Ask user for a number, print its multiplication table (1-10).

# %%
# Write your code here

# %% [markdown]
# ## Exercise 4: Sum of Numbers
# Calculate sum of numbers from 1 to 100.

# %%
# Write your code here

# %% [markdown]
# ## Challenge: Pattern
# Print:
# ```
# *
# **
# ***
# ****
# *****
# ```

# %%
# Write your code here
