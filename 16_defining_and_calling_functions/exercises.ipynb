# %% [markdown]
# # Topic 16: Functions - Exercises
#
# Practice defining and calling functions.
#
# ---

# %% [markdown]
# ## Exercise 1: Simple Function
# Define a function `say_hello()` that prints "Hello, World!". Call it.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 2: Function with Parameter
# Create function `greet(name)` that prints personalized greeting.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 3: Addition Function
# Create `add(a, b)` that returns the sum.

# %%
# Write your code here

# %% [markdown]
# ## Challenge: Calculator
# Create 4 functions: add, subtract, multiply, divide. Test all.

# %%
# Write your code here
