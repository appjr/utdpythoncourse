# %% [markdown]
# # Topic 7: Comparison & Logical Operators - Exercises
#
# ## Instructions
# Practice using comparison and logical operators.
#
# **Remember:**
# - == checks equality, != checks inequality
# - >, <, >=, <= for comparisons
# - and, or, not for combining conditions
#
# ---

# %% [markdown]
# ## Exercise 1: Basic Comparisons
#
# Test these comparisons and print the results:
# 1. Is 10 equal to 10?
# 2. Is 5 greater than 8?
# 3. Is 3 less than or equal to 3?

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 2: Age Checker
#
# Ask for the user's age and check:
# 1. Are they 18 or older?
# 2. Are they under 13?

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 3: Password Validator
#
# Ask for a password and check if it matches "Python2024".
# Print True if correct, False if not.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 4: Number Range
#
# Ask for a number and check if it's between 1 and 100 (inclusive).

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 5: AND Operator
#
# Check if a number is:
# - Greater than 10 AND less than 20

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 6: OR Operator
#
# Check if a number is:
# - Less than 0 OR greater than 100

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 7: NOT Operator
#
# Create a variable `is_raining = True`.
# Use NOT to check if it's NOT raining.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 8: Discount Eligibility
#
# Ask for age. Check if they get a discount:
# - Age under 12 OR age 65 or over

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 9: Temperature Check
#
# Ask for temperature. Check if it's comfortable (between 68 and 78 degrees).

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 10: Grade Checker
#
# Ask for a test score (0-100). Check:
# 1. Is it 90 or above? (A)
# 2. Is it below 60? (F)

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Challenge Exercise 1: Login System
#
# Ask for username AND password.
# Check if BOTH match:
# - Username: "admin"
# - Password: "pass123"

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Challenge Exercise 2: Driving Eligibility
#
# Ask for:
# - Age
# - Has license? (True/False)
#
# Check if they can drive (age >= 16 AND has_license)

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Challenge Exercise 3: Complex Conditions
#
# Ask for a number. Check if:
# - It's even (divisible by 2) AND between 10 and 50

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Reflection
#
# Great work! You've practiced:
# - Comparison operators (==, !=, >, <, >=, <=)
# - Logical operators (and, or, not)
# - Combining conditions
# - Real-world decision making
#
# **Next:** Check solutions, then learn Conditional Statements!
