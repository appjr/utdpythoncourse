# %% [markdown]
# # Topic 6: User Input & Type Casting - Exercises
#
# ## Instructions
# Practice getting user input and converting between data types.
#
# **Remember:**
# - input() always returns a string
# - Use int() for whole numbers
# - Use float() for decimals
# - Use str() to convert numbers to text
#
# ---

# %% [markdown]
# ## Exercise 1: Simple Greeting
#
# Ask the user for their name and age, then print a greeting message.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 2: Age Calculator
#
# Ask the user for their age, then calculate and print:
# 1. How old they'll be next year
# 2. How old they were 5 years ago

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 3: Simple Calculator
#
# Ask the user for two numbers, then print their sum, difference, product, and quotient.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 4: Rectangle Area
#
# Ask the user for the length and width of a rectangle, then calculate and print the area.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 5: Temperature Converter
#
# Ask the user for a temperature in Fahrenheit, convert it to Celsius, and print the result.
#
# Formula: C = (F - 32) × 5/9

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 6: Shopping Total
#
# Ask the user for:
# - Item name
# - Price per item
# - Quantity
#
# Calculate and print the total cost.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 7: Circle Area
#
# Ask the user for the radius of a circle, then calculate and print its area.
#
# Formula: Area = π × radius²
# (Use 3.14159 for π)

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 8: Miles to Kilometers
#
# Ask the user for a distance in miles, convert it to kilometers, and print the result.
#
# Formula: kilometers = miles × 1.60934

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 9: Tip Calculator
#
# Ask the user for:
# - Bill amount
# - Tip percentage (as a whole number, e.g., 15 for 15%)
#
# Calculate and print:
# - Tip amount
# - Total bill (with tip)

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 10: Time Converter
#
# Ask the user for a number of seconds, then convert and print:
# - Hours
# - Minutes
# - Remaining seconds
#
# Example: 3665 seconds = 1 hour, 1 minute, 5 seconds

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Challenge Exercise 1: Personal Profile
#
# Create an interactive program that asks for:
# - Name
# - Age
# - Height (in feet)
# - Favorite color
#
# Then create a nicely formatted profile card displaying all information.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Challenge Exercise 2: Restaurant Bill Splitter
#
# Ask the user for:
# - Total bill amount
# - Number of people
# - Tip percentage
#
# Calculate and print:
# - Tip amount
# - Total with tip
# - Amount per person

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Challenge Exercise 3: Grade Calculator
#
# Ask the user for three test scores (0-100), then:
# 1. Calculate the average
# 2. Print each score
# 3. Print the average
# 4. Print a message about the average

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Bonus Challenge: Unit Converter
#
# Create a comprehensive unit converter that asks the user for:
# - A value
# - What unit it's in (feet/meters)
#
# Then converts and displays the value in the other unit.
#
# Conversion: 1 meter = 3.28084 feet

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Reflection
#
# Excellent work! You've practiced:
# - Getting user input with input()
# - Converting strings to int and float
# - Converting numbers to strings
# - Building interactive programs
# - Performing calculations with user data
# - Creating formatted output
#
# **Next:** Check solutions, then move to Comparison & Logical Operators!
