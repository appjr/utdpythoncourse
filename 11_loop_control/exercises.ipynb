# %% [markdown]
# # Topic 11: Loop Control - Exercises
#
# Practice using break and continue.
#
# ---

# %% [markdown]
# ## Exercise 1: Find First Even
# Use break to find and print the first even number in [1, 3, 5, 8, 9, 12].

# %%
# Write your code here

# %% [markdown]
# ## Exercise 2: Skip Multiples of 3
# Print numbers 1-20, but skip multiples of 3 using continue.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 3: Password Attempts
# Give user 3 attempts to enter correct password ("secret"). Use break when correct.

# %%
# Write your code here

# %% [markdown]
# ## Challenge: Prime Number Check
# Ask for a number. Check if it's prime using loops with break.

# %%
# Write your code here
