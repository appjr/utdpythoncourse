# %% [markdown]
# # Topic 8: Conditional Statements - Exercises
#
# ## Instructions
# Practice using if, elif, and else statements.
#
# **Remember:**
# - Indentation is crucial!
# - Use == for comparison, not =
# - Only one block executes
#
# ---

# %% [markdown]
# ## Exercise 1: Voting Eligibility
#
# Ask for age. If 18 or older, print "You can vote", otherwise "You cannot vote yet".

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 2: Positive or Negative
#
# Ask for a number. Print whether it's positive, negative, or zero.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 3: Grade Calculator
#
# Ask for a test score (0-100). Print the letter grade:
# - 90-100: A
# - 80-89: B
# - 70-79: C
# - 60-69: D
# - Below 60: F

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 4: Even or Odd
#
# Ask for a number. Print whether it's even or odd.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 5: Password Checker
#
# Set correct_password = "python123"
# Ask user for password. Print "Access granted" or "Access denied".

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 6: Temperature Warning
#
# Ask for temperature. Print warnings:
# - Above 100: "Extreme heat warning"
# - Above 90: "Hot day"
# - Below 32: "Freezing"
# - Otherwise: "Normal temperature"

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 7: Movie Rating
#
# Ask for age. Determine allowed movie ratings:
# - Under 13: G and PG only
# - 13-16: G, PG, and PG-13
# - 17+: All ratings including R

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 8: Discount Calculator
#
# Ask for purchase amount. Apply discount:
# - $100+: 20% off
# - $50-99: 10% off
# - Under $50: No discount
#
# Print final price.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Challenge: Login System
#
# Create a login system:
# 1. Ask for username and password
# 2. Correct: "admin" / "password123"
# 3. Check both, print appropriate message

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Reflection
#
# Excellent! You've practiced:
# - if statements
# - if-else statements
# - if-elif-else chains
# - Making decisions in code
#
# **Next:** while Loops!
