# %% [markdown]
# # Topic 13: Lists - Exercises
#
# Practice working with lists.
#
# ---

# %% [markdown]
# ## Exercise 1: Create and Print
# Create a list of 5 favorite foods. Print each one.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 2: Add Items
# Start with empty list. Use append() to add 5 numbers.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 3: Shopping List
# Create shopping list, add 3 items, remove 1, print final list.

# %%
# Write your code here

# %% [markdown]
# ## Challenge: Todo List Manager
# Create todo list with add/remove/display functionality.

# %%
# Write your code here
