# %% [markdown]
# # Topic 5: Basic Operators - Exercises
#
# ## Instructions
# Complete each exercise using the arithmetic and assignment operators you've learned.
#
# **Operators to practice:**
# - +, -, *, /, **, //, %
# - +=, -=, *=, /=
#
# ---

# %% [markdown]
# ## Exercise 1: Basic Arithmetic
#
# Calculate and print the result of:
# 1. 25 + 17
# 2. 100 - 43
# 3. 12 * 8
# 4. 144 / 12

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 2: Temperature Converter
#
# Convert 75°F to Celsius using the formula: C = (F - 32) × 5/9
#
# Store the result in a variable and print it.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 3: Exponentiation
#
# Calculate:
# 1. 3 to the power of 4
# 2. 10 squared
# 3. The square root of 64 (hint: use ** 0.5)

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 4: Floor Division and Modulus
#
# Given 47 items and boxes that hold 6 items each:
# 1. How many full boxes do you need? (use //)
# 2. How many items are left over? (use %)

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 5: Order of Operations
#
# Calculate the result of this expression: 10 + 5 * 2
#
# Then calculate it again with parentheses: (10 + 5) * 2
#
# Compare the results. Are they different?

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 6: Rectangle Area and Perimeter
#
# Given a rectangle with length = 12 and width = 7:
# 1. Calculate the area (length × width)
# 2. Calculate the perimeter (2 × (length + width))

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 7: Assignment Operators
#
# Start with `score = 50`. Using assignment operators:
# 1. Add 10 to score (use +=)
# 2. Print the score
# 3. Multiply score by 2 (use *=)
# 4. Print the score
# 5. Subtract 30 from score (use -=)
# 6. Print the final score

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 8: Time Converter
#
# Convert 245 minutes to hours and minutes:
# 1. Use // to get hours
# 2. Use % to get remaining minutes
# 3. Print in format: "245 minutes = X hours and Y minutes"

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 9: Circle Calculations
#
# Given a circle with radius = 7 and π = 3.14159:
# 1. Calculate circumference (2 × π × radius)
# 2. Calculate area (π × radius²)

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Exercise 10: Shopping Cart Total
#
# Calculate the total cost of:
# - 3 books at $12.99 each
# - 2 pens at $1.50 each
# - 1 notebook at $5.99
#
# Print the total.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Challenge Exercise 1: Tip Calculator
#
# Create a tip calculator:
# - Bill amount: $85.50
# - Tip percentage: 18%
# - Calculate tip amount
# - Calculate total (bill + tip)
# - Print both values nicely formatted

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Challenge Exercise 2: Compound Interest
#
# Calculate compound interest:
# - Principal: $5000
# - Annual rate: 5% (0.05)
# - Time: 3 years
# - Formula: Amount = Principal × (1 + rate)^time
#
# Calculate and print the final amount.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Challenge Exercise 3: BMI Calculator
#
# Calculate Body Mass Index (BMI):
# - Weight: 70 kg
# - Height: 1.75 meters
# - Formula: BMI = weight / (height²)
#
# Calculate and print the BMI.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Challenge Exercise 4: Distance Calculator
#
# Calculate distance traveled:
# - Speed: 65 miles per hour
# - Time: 2.5 hours
# - Formula: Distance = Speed × Time
#
# Then calculate how much gas used if the car gets 30 miles per gallon.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Bonus Challenge: Even or Odd Checker
#
# Check if numbers are even or odd using the modulus operator:
# 1. Check if 42 is even or odd (42 % 2 should be 0 for even)
# 2. Check if 17 is even or odd
# 3. Check if 100 is even or odd
#
# For each, print whether it's even or odd based on the remainder.

# %%
# Write your code here

# %% [markdown]
# ---
#
# ## Reflection
#
# Great job! You've practiced:
# - All arithmetic operators (+, -, *, /, **, //, %)
# - Assignment operators (+=, -=, *=, /=)
# - Order of operations (PEMDAS)
# - Real-world calculations
# - Problem-solving with math
#
# **Next:** Check solutions, then move to Getting User Input & Type Casting!
