# %% [markdown]
# # Topic 22: Inspecting DataFrames
#
# ## Learning Objectives
# - Inspect DataFrame structure
# - Get summary statistics
#
# ---

# %% [markdown]
# ## 22.1 DataFrame Info

# %%
import pandas as pd

df = pd.read_csv('data.csv')
print(df.info())

# %% [markdown]
# ## 22.2 Summary Statistics

# %%
# Get statistics
print(df.describe())

# %% [markdown]
# ## 22.3 Shape and Columns

# %%
print(df.shape)
print(df.columns)

# %% [markdown]
# ---
#
# ## Key Takeaways
#
# ✅ `.info()` shows DataFrame structure
#
# ✅ `.describe()` shows statistics
#
# ✅ `.shape` shows dimensions
#
# ---
