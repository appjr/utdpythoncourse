# %% [markdown]
# # Topic 15: Dictionaries - Exercises
#
# Practice working with dictionaries.
#
# ---

# %% [markdown]
# ## Exercise 1: Create Dictionary
# Create a dictionary with your information: name, age, city.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 2: Phone Book
# Create phone book dictionary with 3 contacts. Print all names.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 3: Update Dictionary
# Create student dict, add new grade, update age, print all items.

# %%
# Write your code here

# %% [markdown]
# ## Challenge: Word Counter
# Count frequency of words in a sentence using a dictionary.

# %%
# Write your code here
