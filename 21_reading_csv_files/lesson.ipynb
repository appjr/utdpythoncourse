# %% [markdown]
# # Topic 21: Reading CSV Files## Learning Objectives- Read CSV files with Pandas- Understand DataFrame basics---

# %% [markdown]
# ## 21.1 Reading CSV Files

# %%
import pandas as pd# Read CSV filedf = pd.read_csv('data.csv')print(df.head())

# %% [markdown]
# ## 21.2 Viewing Data

# %%
# View first rowsprint(df.head())# View last rowsprint(df.tail())

# %% [markdown]
# ---## Key Takeaways✅ Use `pd.read_csv()` to read CSV files✅ Use `.head()` and `.tail()` to preview data---
