# %% [markdown]
# # Topic 20: Introduction to Pandas## Learning Objectives- Understand what Pandas is- Create DataFrames and Series- Understand basic Pandas data structures---

# %% [markdown]
# ## 20.1 What is Pandas?Pandas is a powerful Python library for data analysis and manipulation.

# %% [markdown]
# ## 20.2 Installing and Importing Pandas

# %%
# Import pandasimport pandas as pdprint("Pandas version:", pd.__version__)

# %% [markdown]
# ## 20.3 Creating a Series

# %%
# Create a Seriesdata = pd.Series([1, 2, 3, 4, 5])print(data)

# %% [markdown]
# ## 20.4 Creating a DataFrame

# %%
# Create a DataFramedata = {    'Name': ['Alice', 'Bob', 'Charlie'],    'Age': [25, 30, 35],    'City': ['NYC', 'LA', 'Chicago']}df = pd.DataFrame(data)print(df)

# %% [markdown]
# ---## Key Takeaways✅ Pandas is for data analysis✅ Series: 1D labeled array✅ DataFrame: 2D labeled table---**Next**: Reading CSV Files
