# %% [markdown]
# # Topic 20 Exercises: Introduction to Pandas

# %% [markdown]
# ## Exercise 1Create a Series with 5 numbers.

# %%
import pandas as pd# Your code here

# %% [markdown]
# ## Exercise 2Create a DataFrame with student data.

# %%
# Your code here
