# %% [markdown]
# # Topic 18 Exercises: Introduction to Modules
#
# Complete the following exercises to practice working with modules.

# %% [markdown]
# ## Exercise 1: Using the math Module
#
# Calculate the area of a circle with radius 7 using `math.pi`.

# %%
import math

# Your code here
radius = 7
area = # Complete this line
print(f"Area: {area}")

# %% [markdown]
# ## Exercise 2: Random Numbers
#
# Generate a random number between 1 and 100.

# %%
import random

# Your code here

# %% [markdown]
# ## Exercise 3: Dice Roller
#
# Create a function that simulates rolling two dice and returns their sum.

# %%
import random

def roll_two_dice():
    # Your code here
    pass

# Test it
print("You rolled:", roll_two_dice())

# %% [markdown]
# ## Exercise 4: Module Alias
#
# Import the math module with alias 'm' and calculate the square root of 144.

# %%
# Your code here
