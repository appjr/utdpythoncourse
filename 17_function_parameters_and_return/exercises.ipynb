# %% [markdown]
# # Topic 17: Function Parameters & Return Values - Exercises
#
# Practice working with function parameters and return values.

# %% [markdown]
# ---
# ## Exercise 1: Calculate Rectangle Area
#
# Define function `rectangle_area(length, width)` that returns the area.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 2: Temperature Converter
#
# Create `celsius_to_fahrenheit(celsius)` that returns temperature in Fahrenheit.
#
# Formula: F = C × 9/5 + 32

# %%
# Write your code here

# %% [markdown]
# ## Exercise 3: Default Parameters
#
# Create `make_greeting(name, greeting="Hello")` with a default greeting.

# %%
# Write your code here

# %% [markdown]
# ## Exercise 4: Multiple Return Values
#
# Create `min_max(numbers)` that returns both minimum and maximum from a list.

# %%
# Write your code here

# %% [markdown]
# ## Challenge: Statistics Calculator
#
# Create `calculate_stats(numbers)` that returns sum, average, minimum, and maximum.

# %%
# Write your code here
